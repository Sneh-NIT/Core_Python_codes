# %%
#GUI - graphical user interface
import tkinter as tk

# %%
import tkinter as tk    # as - alias

# %%
a = tk.Tk()

# %%
a.mainloop()

# %%
a = tk.Tk(className="gui")
a.geometry('800x500')
a.config(bg="#F7E1E1")

# %%
tk?
# Out:
# Type:        module
# String form: <module 'tkinter' from 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\\Lib\\tkinter\\__init__.py'>
# File:        c:\program files\windowsapps\pythonsoftwarefoundation.python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\lib\tkinter\__init__.py
# Docstring:
# Wrapper functions for Tcl/Tk.
#
# Tkinter provides classes which allow the display, positioning and
# control of widgets. Toplevel widgets are Tk and Toplevel. Other
# widgets are Frame, Label, Entry, Text, Canvas, Button, Radiobutton,
# Checkbutton, Scale, Listbox, Scrollbar, OptionMenu, Spinbox
# LabelFrame and PanedWindow.
#
# Properties of the widgets are specified with keyword arguments.
# Keyword arguments have the same name as the corresponding options
# under Tk.
#
# Widgets are positioned with one of the geometry managers Place, Pack
# or Grid. These managers can be called with methods place, pack, grid
# available in every Widget.
#
# ...

# %%
tk?
# Out:
# Type:        module
# String form: <module 'tkinter' from 'C:\\Users\\PC\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\tkinter\\__init__.py'>
# File:        c:\users\pc\appdata\local\programs\python\python314\lib\tkinter\__init__.py
# Docstring:
# Wrapper functions for Tcl/Tk.
#
# Tkinter provides classes which allow the display, positioning and
# control of widgets. Toplevel widgets are Tk and Toplevel. Other
# widgets are Frame, Label, Entry, Text, Canvas, Button, Radiobutton,
# Checkbutton, Scale, Listbox, Scrollbar, OptionMenu, Spinbox
# LabelFrame and PanedWindow.
#
# Properties of the widgets are specified with keyword arguments.
# Keyword arguments have the same name as the corresponding options
# under Tk.
#
# Widgets are positioned with one of the geometry managers Place, Pack
# or Grid. These managers can be called with methods place, pack, grid
# available in every Widget.
#
# Actions are bound to events by options (e.g. the command
# ...

# %%
a = tk.Tk(className='gui')
a.geometry('800x500')
a.config(bg='#F7E1E1')
l = tk.Label(a, text='Calculator', bg='#F7E1E1', font=('Arial', 30, 'bold'), fg='#470101')
l.place(x=280,y=20)
a.mainloop()

# %%
a = tk.Tk(className='gui')
a.geometry('800x500')
a.config(bg='#F7E1E1')
l = tk.Label(a, text = 'Calculator', bg = '#F7E1E1', font=('Arial', 30, 'bold'), fg = '#470101')
l.grid(row = 0, column = 0)
a.mainloop()

# %%
a = tk.Tk(className = 'gui')
a.geometry('800x500')
a.config(bg='#F7E1E1')
l=tk.Label(a, text='Calculator', bg='#F7E1E1', font=('Arial', 30, 'bold'), fg='#470101')
l.place(x=280, y = 20)
l1 = tk.Label(a, text = 'Number 1        =', bg='#F7E1E1', font=('Arial', 20, 'bold'), fg='#470101')
l1.place(x = 130, y = 150)
l2 = tk.Label(a, text = 'Number 2         =', bg='#F7E1E1', font=('Arial', 20, 'bold'), fg = '#470101')
l2.place(x = 130, y = 220)
e1 = tk.Entry(a, font=('cursive', 15, 'bold italic'), bg = '#F0F3FF')
e1.place(x = 400, y = 150)
e2 = tk.Entry(a, font=('cursive', 15, 'bold italic'), bg='#F0F3FF')
e2.place(x = 400, y = 220)
def fn():
    n1 = int(e1.get())
    n2 = int(e2.get())
    l3.config(text=f'Addition of {n1} and {n2} is: {n1+n2}')
    e1.delete(0, tk.END)
    e2.delete(0, tk.END)
    e1.focus()

b = tk.Button(a, text = 'Add', font = ('cursive', 15, 'bold italic'), command=fn, bg='#000E54', fg='white', activebackground='green', activeforeground='yellow')
b.place(x = 130, y = 300)

def fn1():
    n1 = int(e1.get())
    n2 = int(e2.get())
    l3.config(text=f'Multiplication of {n1} and {n2} is: {n1*n2}')
    e1.delete(0, tk.END)
    e2.delete(0, tk.END)
    e1.focus()
def next_entry(event, next_widget):
    next_widget.focus_set()

b1 = tk.Button(a, text = 'Mul', font = ('cursive', 15, 'bold italic'), command = fn1, bg = '#000E54', fg = 'white', activebackground='green', activeforeground='yellow')
b1.place(x=300,y=300)

b2 = tk.Button(a, text='EXIT', font=('cursive', 15, 'bold italic'), command=a.destroy, bg = '#000E54', fg = 'white', activebackground = 'red', activeforeground='yellow')
b2.place(x = 450, y = 300)

l3 = tk.Label(a, text='', font=('cursive', 15, 'bold italic'), bg='#F7E1E1')
l3.place(x = 200, y = 400)

l4 = tk.Label(a, text = 'Result    =', font = ('cursive', 15, 'bold italic'), bg='#F7E1E1')
l4.place(x = 50, y = 400)

e1.bind("<Return>", lambda e: next_entry(e, e2))

b5 = tk.Button(a, text = 'New GUI', command=task)
b5.place(x=400, y =450)
a.mainloop()

# %%
def task():
    b = tk.Tk()
    b.geometry('400x300')
    l = tk.Label(b, text = 'Python class')
    l.pack()
    b.mainloop()
