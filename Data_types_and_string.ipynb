# %%
l = [21,34,32,34,32,34,66,423,23,34,98]

# %%
l.append(115)

# %%
print(l)
# Out:
# [21, 34, 32, 34, 32, 34, 66, 423, 23, 34, 98, 115]

# %%
l.count(34)
# Out:
# 4

# %%
l.extend([10,20,30])

# %%
l
# Out:
# [21, 34, 32, 34, 32, 34, 66, 423, 23, 34, 98, 115, 10, 20, 30]

# %%
l.index(66)
# Out:
# 6

# %%
l.index(23)
# Out:
# 8

# %%
l[8]
# Out:
# 23

# %%
l[8]=500
l
# Out:
# [21, 34, 32, 34, 32, 34, 66, 423, 500, 34, 98, 115, 10, 20, 30]

# %%
l[-4]=100

# %%
l
# Out:
# [21, 34, 32, 34, 32, 34, 66, 423, 500, 34, 98, 100, 10, 20, 30]

# %%
l.insert(5,87)

# %%
l
# Out:
# [21, 34, 32, 34, 32, 87, 34, 66, 423, 500, 34, 98, 100, 10, 20, 30]

# %%
l.pop(8)
# Out:
# 423

# %%
l
# Out:
# [21, 34, 32, 34, 32, 87, 34, 66, 500, 34, 98, 100, 10, 20, 30]

# %%
l.remove(66)

# %%
l
# Out:
# [21, 34, 32, 34, 32, 87, 34, 500, 34, 98, 100, 10, 20, 30]

# %%
l.reverse()

# %%
l
# Out:
# [30, 20, 10, 100, 98, 34, 500, 34, 87, 32, 34, 32, 34, 21]

# %%
l.sort()
l
# Out:
# [10, 20, 21, 30, 32, 32, 34, 34, 34, 34, 87, 98, 100, 500]

# %%
l.sort(reverse=True)

# %%
l
# Out:
# [500, 100, 98, 87, 34, 34, 34, 34, 32, 32, 30, 21, 20, 10]

# %%
x=[65,34,87,45,11,98]
m=x[0]
for i in x:
    if i>m:
        m=i
print(m)
# Out:
# 98

# %%
max(x)
# Out:
# 98

# %%
x=[65,34,87,45,11,98,78]
for i in range(len(x)):
    for j in range(i+1, len(x)):
        if x[j]<x[i]:
            x[j],x[i]=x[i],x[j]
print(x)
# Out:
# [11, 34, 45, 65, 78, 87, 98]

# %%
a = 50
b = 80

# %%
c = a
a = b
b = c
print(a, b)
# Out:
# 80 50

# %%
a,b = b,a
print(a, b)
# Out:
# 50 80

# %%
t = (21, 23, 43, 45, 65)

# %%
type(t)
# Out:
# tuple

# %%
t.count(43)
# Out:
# 1

# %%
t.index(43)
# Out:
# 2

# %%
t
# Out:
# (21, 23, 43, 45, 65)

# %%
t[3]
# Out:
# 45

# %%
t
# Out:
# (21, 23, 43, 45, 65)

# %%
l = list(t)
for i in range(len(l)):
    for j in range(i+1,len(l)):
        if l[j]<l[i]:
            l[j],l[i]=l[i],l[j]
tuple(l)
# Out:
# (21, 23, 43, 45, 65)

# %%
s = 'Python is so easy'

# %%
len(s)
# Out:
# 17

# %%
s
# Out:
# 'Python is so easy'

# %%
new= 'language'

# %%
s + " " + new
# Out:
# 'Python is so easy language'

# %%
s,new
# Out:
# ('Python is so easy', 'language')

# %%
'-'.join((s,new))
# Out:
# 'Python is so easy-language'

# %%
' '.join((s,new))
# Out:
# 'Python is so easy language'

# %%
s
# Out:
# 'Python is so easy'

# %%
s.split()
# Out:
# ['Python', 'is', 'so', 'easy']

# %%
s.split('i')
# Out:
# ['Python ', 's so easy']

# %%
s.center(50,'-')
# Out:
# '----------------Python is so easy-----------------'

# %%
'DATA'.isupper()
# Out:
# True

# %%
'data'.islower()
# Out:
# True

# %%
'928'.isdigit()
# Out:
# True

# %%
'dlfsdj'.upper()
# Out:
# 'DLFSDJ'

# %%
'DFDSPUF'.lower()
# Out:
# 'dfdspuf'

# %%
m = 'This @is delicious'.replace('@','')

# %%
m
# Out:
# 'This is delicious'

# %%
'                  This @is delicious         '.strip()
# Out:
# 'This @is delicious'

# %%
'                  This @is delicious         '.rstrip()
# Out:
# '                  This @is delicious'

# %%
'                  This @is delicious         '.lstrip()
# Out:
# 'This @is delicious         '

# %%
'This @is delicious'.removeprefix('Th')
# Out:
# 'is @is delicious'

# %%
'This @is delicious'.removesuffix('ous')
# Out:
# 'This @is delici'

# %%
d = b'aman'
type(d)
# Out:
# bytes

# %%
s
# Out:
# 'Python is so easy'

# %%
s.encode()
# Out:
# b'Python is so easy'

# %%
s = "HELLO WORLD@123"

# %%
s.capitalize()
# Out:
# 'Hello world'

# %%
s.casefold()
# Out:
# 'hello world@123'

# %%
s.lower()
# Out:
# 'hello world@123'

# %%
text = "Der Fluß"

if text.casefold() == "der fluss":
    print("Match found!")
# Out:
# Match found!

# %%
s.encode()
# Out:
# b'HELLO WORLD@123'

# %%
s
# Out:
# 'HELLO WORLD@123'

# %%
s.endswith("123")
# Out:
# True

# %%
s
# Out:
# 'HELLO WORLD@123'

# %%
print(txt.expandtabs())
# Out:
# H       e       l       l       o

# %%
print(txt.expandtabs(2))
# Out:
# H e l l o

# %%
txt.find('e')
# Out:
# 2

# %%
"{} and {}".format("A","B")
# Out:
# 'A and B'

# %%
data = {'name': "Alice", 'age': 25}
message = "Hello, {name}! You are {age} years old.".format_map(data)
print(message)
# Out:
# Hello, Alice! You are 25 years old.

# %%
message = "Python"

# %%
message.isalnum()
# Out:
# True

# %%
message.isalpha()
# Out:
# True

# %%
text1 = "Hello 123!"
print(text1.isascii())
# Out:
# True

# %%
text2 = "Hèllo"
print(text2.isascii())
# Out:
# False

# %%
"45".isdecimal()
# Out:
# True

# %%
"20".isdigit()
# Out:
# True

# %%
"1variable".isidentifier()
# Out:
# False

# %%
"GDKWS".islower()
# Out:
# False

# %%
"10".isnumeric()
# Out:
# True

# %%
"Hello\nWorld".isprintable()
# Out:
# False

# %%
" ".isspace()
# Out:
# True

# %%
"PYTHON".istitle()
# Out:
# False

# %%
"PYTHON".isupper()
# Out:
# True

# %%
"fds".join("sfd")
# Out:
# 'sfdsffdsd'

# %%
"".ljust(4)
# Out:
# '    '

# %%
text = "HELLO World!"
print(text.lower())
# Out:
# hello world!

# %%
"    Hello World".lstrip()
# Out:
# 'Hello World'

# %%
text = "Hello World 123!"

table = str.maketrans("aeiou", "12345", "0123456789")

result = text.translate(table)
print(result)
# Out:
# H2ll4 W4rld !

# %%
text = "Python-is-fun"
print(text.partition("-"))
# Out:
# ('Python', '-', 'is-fun')

# %%
"sdfsfs".replace("s","f")
# Out:
# 'fdffff'

# %%
txt = "Hello, welcome to my world."
print(txt.rfind("e"))
# Out:
# 13

# %%
text = "Python is Fun 123!"
new_text = text.swapcase()
print(new_text)
# Out:
# pYTHON IS fUN 123!

# %%
"hello world".title()
# Out:
# 'Hello World'

# %%
"sdf".zfill(4)
# Out:
# '0sdf'
