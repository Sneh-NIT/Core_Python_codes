# %%
import seaborn as sns

# %% [raw]
# #pip install seaborn

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df.to_csv("tips_dataset.csv")

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
#seaborn - advance visualization library
#univariate analysis (1 variable)
#bivariate  analysis (2 variable)
#categorial plots
#distribution plots

# %%
sns.countplot(x=df['day'],orient='v')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sales=df.groupby('day',observed=True).sum(numeric_only=True)['total_bill'].values
days=df.groupby('day',observed=True).sum(numeric_only=True)['total_bill'].index

# %%
sales
# Out:
# array([1096.33,  325.88, 1778.4 , 1627.16])

# %%
days
# Out:
# CategoricalIndex(['Thur', 'Fri', 'Sat', 'Sun'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, dtype='category', name='day')

# %%
sns.barplot(x=days,y=sales);

# %%
#distribution plots

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# %%capture
sns.histplot(df['total_bill'],kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x=df['total_bill'],hue=df['sex'], multiple='stack')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x=df['tip'],hue=df['sex'],multiple='stack')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.displot(x=df['total_bill'],y=df['tip'])

# %%
sns.displot(x=df['total_bill'],y=df['tip'],kind='kde')

# %%
sns.distplot(df['total_bill'],bins=30)
# Out:
# /tmp/ipykernel_1850/167772028.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'],bins=30)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.boxplot(y=df['total_bill'],x=df['day'],hue=df['sex'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(y=df['total_bill'],x=df['day'],hue=df['sex'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(df)

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.regplot(x=df['total_bill'],y=df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=df,x='total_bill',y='tip')

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'])

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'],kind='hist')

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'],kind='hex')

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'],kind='kde')
